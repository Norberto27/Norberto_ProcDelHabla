# %%
# instalo wordcloud para generar la nube de palabras
# !pip install wordcloud

# %%
# Importar librerías: WordCloud para crear la nube de palabras y matplotlib, para mostrar la nube
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Creo un texto vinculado a la posibilidad de usar PH e IA  en mi actividad de coach de vida

text = """El Poder del Procesamiento del Habla en el Coaching de Vida

Como coach de vida, mi enfoque está en ayudar a las personas a identificar y superar barreras personales para alcanzar su máximo potencial. Una herramienta clave en este proceso es la comunicación efectiva, tanto verbal como no verbal. Aquí es donde el procesamiento del habla, impulsado por la inteligencia artificial, ofrece un recurso invaluable.

El análisis del habla permite identificar patrones en el tono, la entonación y las emociones expresadas, lo que ayuda a comprender mejor los sentimientos y pensamientos subyacentes de una persona. Esto permite un enfoque más personalizado y preciso en las sesiones de coaching, logrando una conexión más profunda con el cliente.

La IA aplicada al procesamiento del habla facilita una comprensión más completa de las necesidades de cada individuo, potenciando mi capacidad como coach para guiar a mis clientes hacia su crecimiento personal y profesional."""

# Crear un objeto WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# %%
# A continuacion, muestro la imagen generada
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# Modifico el ejemplo anterior agregando palabras en español que no quiero que considere para crear la nube de palabras. Estas son las stop_words por ej: y, de, la, en, entre otras

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Texto original que tome para el desempeño
text = """El Poder del Procesamiento del Habla en el Coaching de Vida

Como coach de vida, mi enfoque está en ayudar a las personas a identificar y superar barreras personales para alcanzar su máximo potencial. Una herramienta clave en este proceso es la comunicación efectiva, tanto verbal como no verbal. Aquí es donde el procesamiento del habla, impulsado por la inteligencia artificial, ofrece un recurso invaluable.

El análisis del habla permite identificar patrones en el tono, la entonación y las emociones expresadas, lo que ayuda a comprender mejor los sentimientos y pensamientos subyacentes de una persona. Esto permite un enfoque más personalizado y preciso en las sesiones de coaching, logrando una conexión más profunda con el cliente.

La IA aplicada al procesamiento del habla facilita una comprensión más completa de las necesidades de cada individuo, potenciando mi capacidad como coach para guiar a mis clientes hacia su crecimiento personal y profesional."""


# Definir stopwords en español
stopwords_es = set(STOPWORDS)
stopwords_es.update(["con", "que", "está", "esto", "los", "para", "un", "mi", "del", "una", "el", "la", "en", "y", "o", "de", "a", "se", "es", "al", "como", "por", "no", "su", "más", "pero", "si", "este", "esta", "eso", "esa", "todo", "todos", "todas", "cada", "cual", "cualquier", "algo", "alguna", "algún", "ningún", "ninguna", "ninguno", "otro", "otros", "otras", "sobre", "entre", "durante", "desde", "hasta", "también", "así", "mismo", "misma", "mismo", "misma", "tan", "tanto", "tanta", "muy", "poco", "poca", "poco", "nada", "solo", "sola", "solo", "sola", "siempre", "nunca", "jamás", "casi", "aproximadamente", "cerca", "lejos", "antes", "después", "ahora", "hoy", "ayer", "mañana", "luego", "mientras", "mientras tanto", "después de", "antes de", "durante", "sin", "aunque", "a pesar de", "debido a", "gracias a", "por qué", "cómo", "dónde", "cuándo", "quién", "qué", "cuál"])

# Crear un objeto WordCloud con stopwords en español
wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords=stopwords_es).generate(text)

# Muestro la nueva imagen generada
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# EJERCICIO RESOLUCION
#
#
# Objetivo: El objetivo de este ejercicio es crear una nube de palabras a partir de un texto en español relacionado con mi actividad de coaching de vida y el procesamiento del habla.
#
# Fuente del texto: He utilizado un texto original creado por mí, enfocado en la interacción entre el coaach y cliente con el objeto de optimizar la relacion entre ambos en base a una comunicacion directa y una escucha activa y lo rearme a partir de las materias que voy viendo en la carrera y en especial por el impacto que me genera el procesamiento del habla en su relacion con el coaching de vida.
#
# Pasos Realizados:
#
# Instalé la librería wordcloud para generar la nube de palabras.
# Definí un texto el español, utilizando múltiples líneas.
# Añadí un conjunto de palabras de parada (stopwords) en español para evitar que estas aparezcan en la nube. Tendria que mejorar esta etapa dado que en el segundo ensayo me siguen apareciendo palabra sin sentido que se me escaparon.
# Utilicé la librería matplotlib para mostrar la nube de palabras generada.

# %%
# instalo wordcloud para generar la nube de palabras
# !pip install wordcloud

# Importar librerías: WordCloud para crear la nube de palabras y matplotlib, para mostrar la nube
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Creo un texto vinculado a la posibilidad de usar PH e IA  en mi actividad de coach de vida

text = """El Poder del Procesamiento del Habla en el Coaching de Vida

Como coach de vida, mi enfoque está en ayudar a las personas a identificar y superar barreras personales para alcanzar su máximo potencial. Una herramienta clave en este proceso es la comunicación efectiva, tanto verbal como no verbal. Aquí es donde el procesamiento del habla, impulsado por la inteligencia artificial, ofrece un recurso invaluable.

El análisis del habla permite identificar patrones en el tono, la entonación y las emociones expresadas, lo que ayuda a comprender mejor los sentimientos y pensamientos subyacentes de una persona. Esto permite un enfoque más personalizado y preciso en las sesiones de coaching, logrando una conexión más profunda con el cliente.

La IA aplicada al procesamiento del habla facilita una comprensión más completa de las necesidades de cada individuo, potenciando mi capacidad como coach para guiar a mis clientes hacia su crecimiento personal y profesional."""

# Crear un objeto WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# A continuacion, muestro la imagen generada
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Texto original que tome para el desempeño
text = """El Poder del Procesamiento del Habla en el Coaching de Vida

Como coach de vida, mi enfoque está en ayudar a las personas a identificar y superar barreras personales para alcanzar su máximo potencial. Una herramienta clave en este proceso es la comunicación efectiva, tanto verbal como no verbal. Aquí es donde el procesamiento del habla, impulsado por la inteligencia artificial, ofrece un recurso invaluable.

El análisis del habla permite identificar patrones en el tono, la entonación y las emociones expresadas, lo que ayuda a comprender mejor los sentimientos y pensamientos subyacentes de una persona. Esto permite un enfoque más personalizado y preciso en las sesiones de coaching, logrando una conexión más profunda con el cliente.

La IA aplicada al procesamiento del habla facilita una comprensión más completa de las necesidades de cada individuo, potenciando mi capacidad como coach para guiar a mis clientes hacia su crecimiento personal y profesional."""


# Definir stopwords en español
stopwords_es = set(STOPWORDS)
stopwords_es.update(["con", "que", "está", "esto", "los", "para", "un", "mi", "del", "una", "el", "la", "en", "y", "o", "de", "a", "se", "es", "al", "como", "por", "no", "su", "más", "pero", "si", "este", "esta", "eso", "esa", "todo", "todos", "todas", "cada", "cual", "cualquier", "algo", "alguna", "algún", "ningún", "ninguna", "ninguno", "otro", "otros", "otras", "sobre", "entre", "durante", "desde", "hasta", "también", "así", "mismo", "misma", "mismo", "misma", "tan", "tanto", "tanta", "muy", "poco", "poca", "poco", "nada", "solo", "sola", "solo", "sola", "siempre", "nunca", "jamás", "casi", "aproximadamente", "cerca", "lejos", "antes", "después", "ahora", "hoy", "ayer", "mañana", "luego", "mientras", "mientras tanto", "después de", "antes de", "durante", "sin", "aunque", "a pesar de", "debido a", "gracias a", "por qué", "cómo", "dónde", "cuándo", "quién", "qué", "cuál"])

# Crear un objeto WordCloud con stopwords en español
wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords=stopwords_es).generate(text)

# Muestro la nueva imagen generada
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
